# %%
# %cd
# Out:
# C:\Users\USER

# %%
import os

path = 'C:\\Users\\USER\\labels_S8\\labels\\'

list = os.listdir(path)
print(list)
# Out:
# ['003d902f-S8-20230416-F99-192.txt', '01df6dd9-S8-20230421-F99-18.txt', '0342da52-S8-20230417-F55-3.txt', '039f8faf-S8-20230416-F99-108.txt', '0459f1fa-S8-20230416-F3-3.txt', '04c263e9-S8-20230416-F99-91.txt', '04d8866b-S8-20230416-F99-100.txt', '07b6c69d-S8-20230416-F99-294.txt', '0817c4e5-S8-20230416-F99-150.txt', '082dee96-S8-20230417-F99-31.txt', '0a421ede-S8-20230416-F99-135.txt', '0a72b745-S8-20230414-F41-7.txt', '0af63409-S8-20230416-F99-177.txt', '0b2c3a97-S8-20230416-F99-220.txt', '0b30dbde-S8-20230416-F99-291.txt', '0b5dcddc-S8-20230416-F99-97.txt', '0b825ae9-S8-20230420-F22-3.txt', '0be7a755-S8-20230420-F22-2.txt', '0cfcacaf-S8-20230416-F53-2.txt', '0d31a959-S8-20230416-F99-268.txt', '0f2e9608-S8-20230416-F99-227.txt', '0f3fe976-S8-20230417-F99-16.txt', '0fc6c38c-S8-20230421-F99-28.txt', '1075e4ff-S8-20230417-F99-14.txt', '12cb65d5-S8-20230421-F99-1.txt', '13712689-S8-20230416-F99-247.txt', '137b5563-S8-20230416-F99-27.txt', '13e3f0a7-S8-20230416-F99-0.txt', '164fee3b-S8-2
# ...

# %%
def replace(filelist, num, path):
    f = open(path + file, 'r')
    line = f.read()
    line = line.split(' ')
    
    line[0] = num
    line = ' '.join(line)
    print(line)
    
    f.close()
    
    f = open(path + file, 'w')
    f.write(line)
    f.close

# %% [markdown]
# ### S8 변경

# %%
path = 'C:\\Users\\USER\\labels_S8\\labels\\'
list = os.listdir(path)

for file in list:
    replace(file, '8', path)
# Out:
# 8
# 8 0.4225122349102774 0.4739130434782608 0.6590538336052202 0.5913043478260868
#
# 8 0.4449225473321859 0.490967741935484 0.5628227194492255 0.30580645161290326
#
# 8 0.465478841870824 0.5434782608695652 0.8151447661469934 0.5685618729096988
#
# 8 0.5609137055837564 0.5519187358916479 0.6277495769881557 0.7246049661399548
#
# 8 0.5245346869712352 0.5406320541760724 0.5177664974619289 0.6704288939051921
#
# 8 0.4242761692650333 0.467391304347826 0.7015590200445433 0.4665551839464883
#
# 8 0.4959216965742252 0.6152173913043477 0.7210440456769984 0.5869565217391305
#
# 8 0.47308319738988586 0.3804347826086957 0.5285481239804243 0.45652173913043476
#
# 8 0.5120481927710842 0.5870967741935478 0.6764199655765918 0.5677419354838699
#
# 8 0.4653130287648054 0.4954853273137698 0.8020304568527918 0.5846501128668171
#
# 8 0.5478841870824054 0.5451505016722408 0.8106904231625837 0.5451505016722411
#
# 8 0.41370558375634514 0.38826185101580135 0.5566835871404399 0.7539503386004515
#
# ...

# %% [markdown]
# ### S9 변경

# %%
path = 'C:\\Users\\USER\\labels_S9\\labels\\'
list = os.listdir(path)

for file in list:
    replace(file, '9', path)
# Out:
# 9 0.5000000000000001 0.4745889387144986 0.5816733067729085 0.4349775784753359
#
# 9 0.6411359724612737 0.4754838709677419 0.5180722891566265 0.4425806451612903
#
# 9 0.4223107569721115 0.5463378176382659 0.4860557768924301 0.34828101644245146
#
# 9 0.5962301587301587 0.4970238095238095 0.4384920634920635 0.3035714285714285
#
# 9 0.5059523809523808 0.49702380952380937 0.26984126984127005 0.1339285714285713
#
# 9 0.5353339787028076 0.5374193548387097 0.5382381413359146 0.4864516129032259
#
# 9 0.5082284607938045 0.47677419354838707 0.4278799612778316 0.36
#
# 9 0.4303000968054211 0.48193548387096774 0.44240077444336884 0.4374193548387097
#
# 9 0.4896729776247849 0.616774193548387 0.8760757314974182 0.5961290322580645
#
# 9 0.532738095238095 0.540922619047619 0.6210317460317463 0.38541666666666663
#
# 9 0.4531872509960159 0.5433482810164422 0.5318725099601592 0.33931240657698014
#
# 9 0.6035634743875278 0.4632107023411372 0.7171492204899778 0.4548494983277591
#
# ...

# %%
path = 'C:\\Users\\USER\\labels_S9\\labels\\'
filelist = os.listdir(path)

for file in filelist:
    with open(path + file, 'r') as f:
        line = f.read()
        if(line.split(' ')[0] != '9'):
            print(line.split(' ')[0])
        
#         print(line)
